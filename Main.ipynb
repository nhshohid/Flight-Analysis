# %%
import pandas as pd

# %%
files = ["2020","2021","2022"]
dataframes = []

for file in files:
    df = pd.read_csv("Combined_Flights_" + file + ".csv")
    dataframes.append(df)

# %%
dataframes[0].head(10)
# Out:
#    FlightDate      Airline Origin Dest  Cancelled  Diverted  CRSDepTime  \
# 0  2020-09-01  Comair Inc.    PHL  DAY      False     False        1905
# 1  2020-09-02  Comair Inc.    PHL  DAY      False     False        1905
# 2  2020-09-03  Comair Inc.    PHL  DAY      False     False        1905
# 3  2020-09-04  Comair Inc.    PHL  DAY      False     False        1905
# 4  2020-09-05  Comair Inc.    PHL  DAY      False     False        1905
# 5  2020-09-06  Comair Inc.    PHL  DAY      False     False        1905
# 6  2020-09-07  Comair Inc.    PHL  DAY      False     False        1905
# 7  2020-09-08  Comair Inc.    PHL  DAY      False     False        1905
# 8  2020-09-09  Comair Inc.    PHL  DAY      False     False        1800
# 9  2020-09-10  Comair Inc.    PHL  DAY      False     False        1800
#
#    DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  WheelsOn  TaxiIn  \
# 0   1858.0              0.0      -7.0  ...     1914.0    2030.0     4.0
# ...

# %%
dataframes[0].shape
# Out:
# (5022397, 61)

# %%
dataframes[1].shape
# Out:
# (6311871, 61)

# %%
dataframes[2].shape
# Out:
# (4078318, 61)
